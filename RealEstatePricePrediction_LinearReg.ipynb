# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("/content/drive/MyDrive/DE/ML/Datasets/AIML/real_estate_price_size.csv")
data.head()
# Out:
#         price     size
# 0  234314.144   643.09
# 1  228581.528   656.22
# 2  281626.336   487.29
# 3  401255.608  1504.75
# 4  458674.256  1275.46

# %%
data.isna().sum()
# Out:
# price    0
# size     0
# dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   price   100 non-null    float64
#  1   size    100 non-null    float64
# dtypes: float64(2)
# memory usage: 1.7 KB

# %%
data.describe()
# Out:
#                price         size
# count     100.000000   100.000000
# mean   292289.470160   853.024200
# std     77051.727525   297.941951
# min    154282.128000   479.750000
# 25%    234280.148000   643.330000
# 50%    280590.716000   696.405000
# 75%    335723.696000  1029.322500
# max    500681.128000  1842.510000

# %%
sns.scatterplot(x = 'size', y = 'price', data = data, color = 'skyblue')
# Out:
# <Axes: xlabel='size', ylabel='price'>

# %%
 x = data[['size']]
 y = data[['price']]
 from sklearn.model_selection import train_test_split
 xtrain, xtest, ytrain, ytest = train_test_split(x, y, test_size = 0.2, random_state = 32)

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(xtrain, ytrain)
# Out:
# LinearRegression()

# %%
print(model.intercept_, model.coef_)
# Out:
# [105666.27184428] [[216.66036921]]

# %%
model.predict([[1379],[1234]])
# Out:
# array([[404440.92098126],
#        [373025.16744619]])

# %%
plt.scatter(xtrain, ytrain, color = 'skyblue')
plt.plot(xtest, ypred, color = 'r')

# %%
ypred = model.predict(xtest)

from sklearn.metrics import mean_absolute_error, mean_squared_error, root_mean_squared_error, r2_score
print("MAE: ", mean_absolute_error(ypred, ytest))
print("MSE: ", mean_squared_error(ypred, ytest))
print("RMSE: ", root_mean_squared_error(ypred, ytest))
print("R2 Score: ", r2_score(ypred, ytest))
# Out:
# MAE:  40075.831723712465
# MSE:  2140022784.571329
# RMSE:  46260.38028995578
# R2 Score:  0.5088499938644204
